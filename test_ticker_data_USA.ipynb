# %%
'''
Extracting the Ticker Data for USA ETFs (top 100) as test dataset for analytical techniques coding.
The dataframe are named in this format: 'hist_countryname_number'
and the datasets show by day: 'Close Price, 'Dividends', 'Volume', for the past 12 years.  Suggest we use data from 1-Jan-2010 as a clean arbitary date.
'''
# Out:
# 'Extracting the Ticker Data for USA ETFs (top 100) as test dataset for analytical techniques coding.'

# %%
# Importing the top 100 US ETFs

# %%
import yfinance as yf
tickers_US_1 = yf.Tickers('SPY IVV VTI VOO QQQ VEA IEFA AGG VTV IEMG VWO BND VUG IJR IWM IJH IWF GLD VIG EFA')
tickers_US_2 = yf.Tickers('IWD VO VXUS VB VCIT XLF VGT BNDX LQD VCSH XLK VNQ ITOT VYM VEU BSV IVW EEM DIA SCHX')
tickers_US_3 = yf.Tickers('IAU USMV IXUS IWR IWB RSP TIP XLV SCHF MBB IGSB XLE SCHD VBR VV IVE MDY MUB HYG XLI')
tickers_US_4 = yf.Tickers('VT SCHB QUAL SDY XLY ARKK EMB SHY DVY PFF DGRO VGK ESGU SCHP IWN JPST ACWI GOVT VLUE VXF')
tickers_US_5 = yf.Tickers('GDX SLV SCHA SHV VBK VMBS SCZ MINT IWP VHT VOE BIV IWS SCHG EFV MTUM VTIP XLC IEF IUSB')

# %%
hist_US_1 = tickers_US_1.history(period="12y")
hist_US_2 = tickers_US_2.history(period="12y")
hist_US_3 = tickers_US_3.history(period="12y")
hist_US_4 = tickers_US_4.history(period="12y")
# Out:
# [*********************100%***********************]  20 of 20 completed
# [*********************100%***********************]  20 of 20 completed
# [*********************100%***********************]  20 of 20 completed
# [*********************100%***********************]  20 of 20 completed

# %%
hist_US_1[['Close','Dividends','Volume']]
# Out:
#                  Close                                               \
#                    AGG        BND        EFA         GLD       IEFA
# Date
# 2009-05-22   73.316681  54.601673  32.314087   94.150002        NaN
# 2009-05-26   73.150917  54.488773  32.959789   93.760002        NaN
# 2009-05-27   72.747200  54.164051  32.321098   93.449997        NaN
# 2009-05-28   72.776031  54.305180  32.650974   94.239998        NaN
# 2009-05-29   73.554611  54.693489  33.303711   96.199997        NaN
# ...                ...        ...        ...         ...        ...
# 2021-05-17  114.199997  84.980003  79.410004  174.699997  75.389999
# 2021-05-18  114.059998  84.889999  79.580002  175.039993  75.620003
# 2021-05-19  113.900002  84.800003  78.879997  175.160004  74.910004
# 2021-05-20  114.290001  85.080002  79.919998  175.960007  75.970001
# 2021-05-21  114.339996  85.099998  80.029999  176.039993  76.050003
#
# ...

# %%
hist_US_2[['Close','Dividends','Volume']]
# Out:
#                 Close                                                          \
#                  BNDX        BSV         DIA        EEM       ITOT        IVW
# Date
# 2009-05-22        NaN  63.518551   62.783504  24.942884  15.752779   9.614894
# 2009-05-26        NaN  63.438301   64.283524  25.241413  16.160143   9.855636
# 2009-05-27        NaN  63.366074   63.003242  24.950739  15.907023   9.707000
# 2009-05-28        NaN  63.414196   63.654739  25.720627  16.120594   9.840973
# 2009-05-29        NaN  63.606831   64.692665  26.113438  16.346033   9.985419
# ...               ...        ...         ...        ...        ...        ...
# 2021-05-17  56.630001  82.300003  343.649994  52.900002  95.300003  67.540001
# 2021-05-18  56.630001  82.320000  341.109985  53.610001  94.629997  67.000000
# 2021-05-19  56.570000  82.279999  339.440002  53.450001  94.349998  67.029999
# 2021-05-20  56.669998  82.339996  341.519989  53.759998  95.360001  68.089996
# ...

# %%
hist_US_3[['Close','Dividends','Volume']]
# Out:
#                 Close                                                \
#                   HYG        IAU       IGSB         IVE         IWB
# Date
# 2009-05-22  37.067589   9.413000  40.616043   32.156464   38.905270
# 2009-05-26  36.971363   9.373000  40.576366   32.984081   39.952225
# 2009-05-27  37.038708   9.348000  40.746956   32.254257   39.248920
# 2009-05-28  37.168606   9.426000  40.893753   32.720741   39.784382
# 2009-05-29  37.447617   9.628000  40.782642   33.300064   40.455715
# ...               ...        ...        ...         ...         ...
# 2021-05-17  87.050003  17.780001  54.810001  149.720001  233.910004
# 2021-05-18  86.839996  17.799999  54.799999  148.440002  232.100006
# 2021-05-19  86.610001  17.820000  54.759998  147.500000  231.320007
# 2021-05-20  86.980003  17.900000  54.860001  148.270004  234.039993
# 2021-05-21  87.110001  17.920000  54.860001  148.800003  233.789993
#
# ...

# %%
hist_US_4[['Close','Dividends','Volume']]
# Out:
#                 Close                                                 \
#                  ACWI        ARKK       DGRO         DVY         EMB
# Date
# 2009-05-22  26.431919         NaN        NaN   22.734377   53.393013
# 2009-05-26  27.007036         NaN        NaN   23.395903   53.472633
# 2009-05-27  26.556269         NaN        NaN   22.832630   53.609131
# 2009-05-28  26.905998         NaN        NaN   23.133913   53.580708
# 2009-05-29  27.434488         NaN        NaN   23.454845   53.290588
# ...               ...         ...        ...         ...         ...
# 2021-05-17  98.930000  103.309998  50.759998  122.989998  111.169998
# 2021-05-18  98.660004  104.790001  50.340000  121.620003  111.160004
# 2021-05-19  98.199997  102.970001  50.240002  120.639999  110.639999
# 2021-05-20  99.330002  106.589996  50.580002  120.839996  111.410004
# 2021-05-21  99.220001  105.839996  50.650002  121.300003  111.190002
#
# ...
